# %% [markdown]
# # PyTorch webinar - top species subset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
from pathlib import Path

# Get list of stored filed in cloud bucket
root = Path(os.path.expanduser("~"))
! date
# Out:
# Thu Mar 13 12:51:31 PM EDT 2025

# %%
# Path and dataset names
data_path = f"{root}/p-dsgt_clef2025-0/shared/plantclef/data/parquet/"

# Define the path to the train and test parquet files
train_path = f"{data_path}/subset_top5_train"

# Read the parquet files into a spark DataFrame
train_df = pd.read_parquet(train_path)

# Show the data
train_df.info()
train_df.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3760 entries, 0 to 3759
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   species_id        3760 non-null   int32
#  1   image_name        3760 non-null   object
#  2   path              3760 non-null   object
#  3   data              3760 non-null   object
#  4   organ             3760 non-null   object
#  5   obs_id            3760 non-null   int64
#  6   license           3760 non-null   object
#  7   partner           203 non-null    object
#  8   author            3760 non-null   object
#  9   altitude          1660 non-null   float64
#  10  latitude          1660 non-null   float64
#  11  longitude         1660 non-null   float64
#  12  gbif_species_id   3760 non-null   object
#  13  species           3760 non-null   object
#  14  genus             3760 non-null   object
#  15  family            3760 non-null   object
#  16  dataset           3760 non-null   object
#  17  publisher         3641 non-null   object
#  18  references        3641 non-null   object
#  19  url               3760 non-null   object
#  20  learn_tag         3760 non-null   object
#  21  image_backup_url  3760 non-null   object
# dtypes: float64(3), int32(1), int64(1), object(17)
# memory usage: 631.7+ KB
#    species_id                                    image_name  \
# 0     1360257  5a4deafc321f2b653f03cc238160a799b0bbb6b7.jpg
# 1     1360257  a6d9a13ec26cbb04d61861ad5cb4ede8eb4d1ea3.jpg
# 2     1360257  0fec55fc5105e512df08490ecbb55df3393d85c8.jpg
# 3     1360257  6d8d213d8ae8f5d1d9aaf535e8d31954ffd9445e.jpg
# 4     1360257  1394dd991e01ee8d0df038e62debf3bb4d22b55e.jpg
#
#                                                 path  \
# 0  /PlantCLEF2024/train/1360257/5a4deafc321f2b653...
# 1  /PlantCLEF2024/train/1360257/a6d9a13ec26cbb04d...
# 2  /PlantCLEF2024/train/1360257/0fec55fc5105e512d...
# 3  /PlantCLEF2024/train/1360257/6d8d213d8ae8f5d1d...
# 4  /PlantCLEF2024/train/1360257/1394dd991e01ee8d0...
#
#                                                 data organ      obs_id  \
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  bark  1015292920
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  bark  1005087257
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  leaf  4111721487
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  bark  4014994731
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  bark  4112099842
#
#                                           license partner         author  \
# 0                                        cc-by-sa    None   Gabor Graehn
# 1                                        cc-by-sa    None  Jacco Sanders
# 2  http://creativecommons.org/licenses/by-nc/4.0/    None         imrsmf
# 3  http://creativecommons.org/licenses/by-nc/4.0/    None       redeft23
# 4  http://creativecommons.org/licenses/by-nc/4.0/    None  Kari Moreland
#
#    altitude  ...  gbif_species_id               species     genus      family  \
# 0       NaN  ...        3039454.0  Frangula alnus Mill.  Frangula  Rhamnaceae
# 1      51.0  ...        3039454.0  Frangula alnus Mill.  Frangula  Rhamnaceae
# 2       NaN  ...        3039454.0  Frangula alnus Mill.  Frangula  Rhamnaceae
# 3       NaN  ...        3039454.0  Frangula alnus Mill.  Frangula  Rhamnaceae
# 4       NaN  ...        3039454.0  Frangula alnus Mill.  Frangula  Rhamnaceae
#
#     dataset    publisher                                         references  \
# 0  plantnet     plantnet  https://identify.plantnet.org/fr/k-southwester...
# 1  plantnet     plantnet  https://identify.plantnet.org/fr/k-southwester...
# 2      gbif  iNaturalist       https://www.inaturalist.org/photos/268971946
# 3      gbif  iNaturalist       https://www.inaturalist.org/photos/250110403
# 4      gbif  iNaturalist       https://www.inaturalist.org/photos/275334489
#
#                                                  url learn_tag  \
# 0  https://bs.plantnet.org/image/o/5a4deafc321f2b...     train
# 1  https://bs.plantnet.org/image/o/a6d9a13ec26cbb...     train
# 2  https://inaturalist-open-data.s3.amazonaws.com...     train
# 3  https://inaturalist-open-data.s3.amazonaws.com...     train
# 4  https://inaturalist-open-data.s3.amazonaws.com...     train
#
#                                     image_backup_url
# 0  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 1  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 2  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 3  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 4  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
#
# [5 rows x 22 columns]
