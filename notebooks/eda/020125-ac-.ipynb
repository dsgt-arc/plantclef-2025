# %%
# %%bash
# mkdir -p ~/scratch/plantclef/data/wcvp
# wget https://sftp.kew.org/pub/data-repositories/WCVP/wcvp.zip -O ~/scratch/plantclef/data/wcvp/wcvp.zip
# unzip -o ~/scratch/plantclef/data/wcvp/wcvp.zip -d ~/scratch/plantclef/data/wcvp
# Out:
# --2025-02-02 00:28:54--  https://sftp.kew.org/pub/data-repositories/WCVP/wcvp.zip
# Resolving sftp.kew.org (sftp.kew.org)... 20.77.66.27
# Connecting to sftp.kew.org (sftp.kew.org)|20.77.66.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103958587 (99M) [application/zip]
# Saving to: ‘/storage/home/hcoda1/7/acheung46/scratch/plantclef/data/wcvp/wcvp.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  188K 8m59s
#     50K .......... .......... .......... .......... ..........  0%  189K 8m58s
#    100K .......... .......... .......... .......... ..........  0%  562K 6m59s
#    150K .......... .......... .......... .......... ..........  0%  226M 5m14s
#    200K .......... .......... .......... .......... ..........  0%  571K 4m47s
#    250K .......... .......... .......... .......... ..........  0%  168M 3m59s
#    300K .......... .......... .......... .......... ..........  0%  570K 3m50s
# ...
